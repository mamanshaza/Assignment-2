# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
sns.set_theme(style="darkgrid")

# %%
ATTR = pd.read_csv("adds.csv")
pd.set_option('display.max_rows',None)
ATTR
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# 5      32        No  Travel_Frequently       1005  Research & Development
# 6      59        No      Travel_Rarely       1324  Research & Development
# 7      30        No      Travel_Rarely       1358  Research & Development
# 8      38        No  Travel_Frequently        216  Research & Development
# 9      36        No      Travel_Rarely       1299  Research & Development
# 10     35        No      Travel_Rarely        809  Research & Development
# 11     29        No      Travel_Rarely        153  Research & Development
# ...

# %%
Attr_new = ATTR.iloc[:,[1,5,15]]

Attr_new
# Out:
#      Attrition  DistanceFromHome                    JobRole
# 0          Yes                 1            Sales Executive
# 1           No                 8         Research Scientist
# 2          Yes                 2      Laboratory Technician
# 3           No                 3         Research Scientist
# 4           No                 2      Laboratory Technician
# 5           No                 2      Laboratory Technician
# 6           No                 3      Laboratory Technician
# 7           No                24      Laboratory Technician
# 8           No                23     Manufacturing Director
# 9           No                27  Healthcare Representative
# 10          No                16      Laboratory Technician
# 11          No                15      Laboratory Technician
# 12          No                26         Research Scientist
# 13          No                19      Laboratory Technician
# 14         Yes                24      Laboratory Technician
# ...

# %%
sns.scatterplot(data=Attr_new, x="DistanceFromHome", y="JobRole", hue='Attrition')
# Out:
# <AxesSubplot:xlabel='DistanceFromHome', ylabel='JobRole'>

# %%
sns.relplot(
    data=Attr_new, x="DistanceFromHome", y="JobRole",
    col="Attrition", hue="Attrition", kind="scatter")

# %%
sns.boxplot(data=Attr_new, x="DistanceFromHome", y="JobRole")
# Out:
# <AxesSubplot:xlabel='DistanceFromHome', ylabel='JobRole'>

# %%
sns.lineplot(data=Attr_new, x="DistanceFromHome", y="JobRole")
# Out:
# <AxesSubplot:xlabel='DistanceFromHome', ylabel='JobRole'>

# %%
sns.boxplot(
    data=Attr_new, x="DistanceFromHome", y="JobRole",
    notch=True, showcaps=False,
    flierprops={"marker": "x"},
    boxprops={"facecolor": (.4, .6, .8, .5)},
    medianprops={"color": "coral"},)
# Out:
# <AxesSubplot:xlabel='DistanceFromHome', ylabel='JobRole'>

# %%
sns.displot(data = Attr_new, x= 'DistanceFromHome',hue = 'Attrition')

# %%
JobRole = ATTR.groupby("JobRole")["Attrition"]
JobRole = pd.DataFrame(JobRole.value_counts())
JobRole
# Out:
#                                      Attrition
# JobRole                   Attrition
# Healthcare Representative No               122
#                           Yes                9
# Human Resources           No                40
#                           Yes               12
# Laboratory Technician     No               197
#                           Yes               62
# Manager                   No                97
#                           Yes                5
# Manufacturing Director    No               135
#                           Yes               10
# Research Director         No                78
#                           Yes                2
# Research Scientist        No               245
#                           Yes               47
# Sales Executive           No               269
#                           Yes               57
# Sales Representative      No                50
#                           Yes               33

# %%
sns.displot(data = Attr_new, y= 'JobRole',hue = 'Attrition')

# %%
# Distance from home by job role - as attrition yes

Attr_Yes = Attr_new[Attr_new['Attrition']=="Yes"]
Attr_Yes
# Out:
#      Attrition  DistanceFromHome                    JobRole
# 0          Yes                 1            Sales Executive
# 2          Yes                 2      Laboratory Technician
# 14         Yes                24      Laboratory Technician
# 21         Yes                 9       Sales Representative
# 24         Yes                 6         Research Scientist
# 26         Yes                16         Research Scientist
# 33         Yes                 5       Sales Representative
# 34         Yes                 1         Research Scientist
# 36         Yes                 3       Sales Representative
# 42         Yes                25      Laboratory Technician
# 45         Yes                12          Research Director
# 50         Yes                 1      Laboratory Technician
# 51         Yes                 5      Laboratory Technician
# 69         Yes                 9         Research Scientist
# 89         Yes                 9            Sales Executive
# ...

# %%
sns.lineplot(x="DistanceFromHome", y="JobRole", data=Attr_Yes)
# Out:
# <AxesSubplot:xlabel='DistanceFromHome', ylabel='JobRole'>

# %%
#distance from home and job role attrition

sns.histplot(data = Attr_new, x='DistanceFromHome' ,y = 'JobRole', hue='Attrition')
# Out:
# <AxesSubplot:xlabel='DistanceFromHome', ylabel='JobRole'>

# %%
sns.histplot(Attr_Yes, x="DistanceFromHome", hue="JobRole", element="poly")
# Out:
# <AxesSubplot:xlabel='DistanceFromHome', ylabel='Count'>

# %%
# compare average monthly income by Education and Attrition

Attr_new2 = ATTR.iloc[:,[1,6,19]]
pd.set_option('display.max_rows',None)
Attr_new2
# Out:
#      Attrition  Education  MonthlyRate
# 0          Yes          2        19479
# 1           No          1        24907
# 2          Yes          2         2396
# 3           No          4        23159
# 4           No          1        16632
# 5           No          2        11864
# 6           No          3         9964
# 7           No          1        13335
# 8           No          3         8787
# 9           No          3        16577
# 10          No          3        16479
# 11          No          2        12682
# 12          No          1        15170
# 13          No          2         8758
# 14         Yes          3        12947
# 15          No          4        10195
# 16          No          2        15053
# 17          No          2         7324
# 18          No          4        22021
# 19          No          3         4306
# 20          No          2         8232
# 21         Yes          4         6986
# 22          No          4        21293
# ...

# %%
sns.relplot(
    data=Attr_new2.query("Attrition == 'Yes'"), kind="line",
    x="Education", y="MonthlyRate", hue="Attrition",
     estimator=None,)

# %%
sns.relplot(data=Attr_new2.query("Attrition == 'Yes'"), x="Education", y="MonthlyRate")

# %%
sns.boxplot(
    data=Attr_new2.query("Attrition == 'Yes'"), x="Education", y="MonthlyRate", hue="Attrition",
    notch=True, showcaps=False,
    flierprops={"marker": "x"},
    boxprops={"facecolor": (.4, .6, .8, .5)},
    medianprops={"color": "coral"},)
# Out:
# <AxesSubplot:xlabel='Education', ylabel='MonthlyRate'>

# %%
sns.displot(data=Attr_new2.query("Attrition == 'Yes'"), x="MonthlyRate", hue = "Attrition", height = 5)

# %%
sns.relplot(data=Attr_Yes2, x="Education", y="MonthlyRate", kind="line")

# %%
sns.boxplot(data=Attr_new2.query("Attrition == 'Yes'"), x="Education", y="MonthlyRate")
# Out:
# <AxesSubplot:xlabel='Education', ylabel='MonthlyRate'>

# %%
sns.histplot(Attr_new2.query("Attrition == 'Yes'"), x="MonthlyRate", hue="Education", element="poly")
# Out:
# <AxesSubplot:xlabel='MonthlyRate', ylabel='Count'>

# %%
sns.relplot(
    data=Attr_new2, kind="line", x="Attrition", y="MonthlyRate", hue ='Education')

# %%
sns.pairplot(Attr_new2, hue ='Attrition')
plt.show()

# %%
Attr_numerized = Attr_new2

for col_name in Attr_numerized.columns:
    if(Attr_numerized[col_name].dtype == 'object'):
        Attr_numerized[col_name]= Attr_numerized[col_name].astype('category')
        Attr_numerized[col_name] = Attr_numerized[col_name].cat.codes
        
Attr_numerized
# Out:
#       Attrition  Education  MonthlyRate
# 0             1          2        19479
# 1             0          1        24907
# 2             1          2         2396
# 3             0          4        23159
# 4             0          1        16632
# 5             0          2        11864
# 6             0          3         9964
# 7             0          1        13335
# 8             0          3         8787
# 9             0          3        16577
# 10            0          3        16479
# 11            0          2        12682
# 12            0          1        15170
# 13            0          2         8758
# 14            1          3        12947
# 15            0          4        10195
# 16            0          2        15053
# 17            0          2         7324
# 18            0          4        22021
# 19            0          3         4306
# 20            0          2         8232
# 21            1          4         6986
# ...

# %%
# Correlation Matrix between all numeric columns

Attr_numerized.corr(method ='pearson')
# Out:
#              Attrition  Education  MonthlyRate
# Attrition     1.000000  -0.031373     0.015170
# Education    -0.031373   1.000000    -0.026084
# MonthlyRate   0.015170  -0.026084     1.000000

# %%
Attr_numerized.corr(method ='kendall')
# Out:
#              Attrition  Education  MonthlyRate
# Attrition     1.000000  -0.027817     0.012462
# Education    -0.027817   1.000000    -0.016106
# MonthlyRate   0.012462  -0.016106     1.000000

# %%
Attr_numerized.corr(method ='spearman')
# Out:
#              Attrition  Education  MonthlyRate
# Attrition     1.000000  -0.030346     0.015258
# Education    -0.030346   1.000000    -0.021214
# MonthlyRate   0.015258  -0.021214     1.000000

# %%
correlation_matrix = Attr_new2.corr(method='pearson')

sns.heatmap(correlation_matrix, annot = True)

plt.title("Correlation matrix for MonthlyRate")

plt.xlabel("MonthlyRate features")

plt.ylabel("MonthlyRate features")

plt.show()

# %%
dataplot=sns.heatmap(Attr_numerized.corr())
  

plt.show()
